# %%
import numpy as np
import pandas as pd

# %%
ls
# Out:
# MatplotLib conti. + Seaborn.ipynb  Pfizer_1.csv
# Matplotlib.ipynb                   directors.csv
# Matplotlib_Revision.ipynb          figure.png
# Pandas_4.ipynb                     gapminder.csv
# Pandas_5.ipynb                     jupyterthemes.ipynb
# Pandas_Rev_conti.ipynb             movies.csv
# Pandas_Revision.ipynb

# %%
df=pd.read_csv("gapminder.csv")

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df["country"]
# Out:
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
#            ...
# 1699       Zimbabwe
# 1700       Zimbabwe
# 1701       Zimbabwe
# 1702       Zimbabwe
# 1703       Zimbabwe
# Name: country, Length: 1704, dtype: object

# %%
df[["country","year"]]
# Out:
#           country  year
# 0     Afghanistan  1952
# 1     Afghanistan  1957
# 2     Afghanistan  1962
# 3     Afghanistan  1967
# 4     Afghanistan  1972
# ...           ...   ...
# 1699     Zimbabwe  1987
# 1700     Zimbabwe  1992
# 1701     Zimbabwe  1997
# 1702     Zimbabwe  2002
# 1703     Zimbabwe  2007
#
# [1704 rows x 2 columns]

# %%
df.head()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
df.head(5)
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
df.head(10)
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106
# 5  Afghanistan  1977    14880372      Asia    38.438  786.113360
# 6  Afghanistan  1982    12881816      Asia    39.854  978.011439
# 7  Afghanistan  1987    13867957      Asia    40.822  852.395945
# 8  Afghanistan  1992    16317921      Asia    41.674  649.341395
# 9  Afghanistan  1997    22227415      Asia    41.763  635.341351

# %%
df.tail()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 1699  Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700  Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701  Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702  Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703  Zimbabwe  2007    12311143    Africa    43.487  469.709298

# %%
df.tail(10)
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 1694  Zimbabwe  1962     4277736    Africa    52.358  527.272182
# 1695  Zimbabwe  1967     4995432    Africa    53.995  569.795071
# 1696  Zimbabwe  1972     5861135    Africa    55.635  799.362176
# 1697  Zimbabwe  1977     6642107    Africa    57.674  685.587682
# 1698  Zimbabwe  1982     7636524    Africa    60.363  788.855041
# 1699  Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700  Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701  Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702  Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703  Zimbabwe  2007    12311143    Africa    43.487  469.709298

# %%
pd.DataFrame([["Aam",23,"Male","ML","Sony",10],
             ["Sam",25,"Male","AI","Sony",10]])
# Out:
#      0   1     2   3     4   5
# 0  Aam  23  Male  ML  Sony  10
# 1  Sam  25  Male  AI  Sony  10

# %%
pd.DataFrame([["Aam",23,"Male","ML","Sony",10],
             ["Sam",25,"Male","AI","Sony",10],
             ["Apple",50,"Male","DS","Alpha",20]])
# Out:
#        0   1     2   3      4   5
# 0    Aam  23  Male  ML   Sony  10
# 1    Sam  25  Male  AI   Sony  10
# 2  Apple  50  Male  DS  Alpha  20

# %%
pd.DataFrame([["Aam",23,"Male","ML","Sony",10],
             ["Sam",25,"Male","AI","Sony",10],
             ["Apple",50,"Male","DS","Alpha",20]],
            columns=["Name","Age","Sex","Profile","Project","Duration"])
# Out:
#     Name  Age   Sex Profile Project  Duration
# 0    Aam   23  Male      ML    Sony        10
# 1    Sam   25  Male      AI    Sony        10
# 2  Apple   50  Male      DS   Alpha        20

# %%
pd.DataFrame({"Name":["Aam","Sam","Apple"]})
# Out:
#     Name
# 0    Aam
# 1    Sam
# 2  Apple

# %%
pd.DataFrame({"Name":["Aam","Sam","Apple"],
             "Age":[23,25,50]})
# Out:
#     Name  Age
# 0    Aam   23
# 1    Sam   25
# 2  Apple   50

# %%
pd.DataFrame({"Name":["Aam","Sam","Apple"],
             "Age":[23,25,50],
             "Sex":["Male","Male","Male"]})
# Out:
#     Name  Age   Sex
# 0    Aam   23  Male
# 1    Sam   25  Male
# 2  Apple   50  Male

# %%
pd.DataFrame({"Name":["Aam","Sam","Apple"],
             "Age":[23,25,50],
             "Sex":["Male","Male","Male"],
             "Profile":["ML","AI","DS"],
             "Project":["Sony","Sony","Alpha"],
             "Duration":[10,10,30]})
# Out:
#     Name  Age   Sex Profile Project  Duration
# 0    Aam   23  Male      ML    Sony        10
# 1    Sam   25  Male      AI    Sony        10
# 2  Apple   50  Male      DS   Alpha        30

# %%
df.columns
# Out:
# Index(['country', 'year', 'population', 'continent', 'life_exp', 'gdp_cap'], dtype='object')

# %%
df.keys()
# Out:
# Index(['country', 'year', 'population', 'continent', 'life_exp', 'gdp_cap'], dtype='object')

# %%
type(df["country"])
# Out:
# pandas.core.series.Series

# %%
type(df[["country"]])
# Out:
# pandas.core.frame.DataFrame

# %%
df['country'].unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'Angola', 'Argentina',
#        'Australia', 'Austria', 'Bahrain', 'Bangladesh', 'Belgium',
#        'Benin', 'Bolivia', 'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'Bulgaria', 'Burkina Faso', 'Burundi', 'Cambodia', 'Cameroon',
#        'Canada', 'Central African Republic', 'Chad', 'Chile', 'China',
#        'Colombia', 'Comoros', 'Congo, Dem. Rep.', 'Congo, Rep.',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Czech Republic',
#        'Denmark', 'Djibouti', 'Dominican Republic', 'Ecuador', 'Egypt',
#        'El Salvador', 'Equatorial Guinea', 'Eritrea', 'Ethiopia',
#        'Finland', 'France', 'Gabon', 'Gambia', 'Germany', 'Ghana',
#        'Greece', 'Guatemala', 'Guinea', 'Guinea-Bissau', 'Haiti',
#        'Honduras', 'Hong Kong, China', 'Hungary', 'Iceland', 'India',
#        'Indonesia', 'Iran', 'Iraq', 'Ireland', 'Israel', 'Italy',
#        'Jamaica', 'Japan', 'Jordan', 'Kenya', 'Korea, Dem. Rep.',
# ...

# %%
df["country"].nunique()
# Out:
# 142

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   country     1704 non-null   object
#  1   year        1704 non-null   int64
#  2   population  1704 non-null   int64
#  3   continent   1704 non-null   object
#  4   life_exp    1704 non-null   float64
#  5   gdp_cap     1704 non-null   float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 80.0+ KB

# %%
df.describe()
# Out:
#              year    population     life_exp        gdp_cap
# count  1704.00000  1.704000e+03  1704.000000    1704.000000
# mean   1979.50000  2.960121e+07    59.474439    7215.327081
# std      17.26533  1.061579e+08    12.917107    9857.454543
# min    1952.00000  6.001100e+04    23.599000     241.165876
# 25%    1965.75000  2.793664e+06    48.198000    1202.060309
# 50%    1979.50000  7.023596e+06    60.712500    3531.846988
# 75%    1993.25000  1.958522e+07    70.845500    9325.462346
# max    2007.00000  1.318683e+09    82.603000  113523.132900

# %%
df.describe(include="all")
# Out:
#             country        year    population continent     life_exp  \
# count          1704  1704.00000  1.704000e+03      1704  1704.000000
# unique          142         NaN           NaN         5          NaN
# top     Afghanistan         NaN           NaN    Africa          NaN
# freq             12         NaN           NaN       624          NaN
# mean            NaN  1979.50000  2.960121e+07       NaN    59.474439
# std             NaN    17.26533  1.061579e+08       NaN    12.917107
# min             NaN  1952.00000  6.001100e+04       NaN    23.599000
# 25%             NaN  1965.75000  2.793664e+06       NaN    48.198000
# 50%             NaN  1979.50000  7.023596e+06       NaN    60.712500
# 75%             NaN  1993.25000  1.958522e+07       NaN    70.845500
# max             NaN  2007.00000  1.318683e+09       NaN    82.603000
#
#               gdp_cap
# count     1704.000000
# unique            NaN
# top               NaN
# freq              NaN
# ...

# %%
df.rename(columns={"country":"CountrY"})
# Out:
#           CountrY  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.rename(columns={"country":"CountrY","year":"YeaR"})
# Out:
#           CountrY  YeaR  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.rename({"country":"CountrY"},axis=1)
# Out:
#           CountrY  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.rename({"country":"CountrY","year":"YeaR"},axis=1)
# Out:
#           CountrY  YeaR  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.drop("year")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [34], in <cell line: 1>()
# ----> 1 df.drop("year")
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
#    4808     self,
#    (...)
#    4815     errors: str = "raise",
#    4816 ):
# ...

# %%
df.drop("year",axis=1)
# Out:
#           country  population continent  life_exp     gdp_cap
# 0     Afghanistan     8425333      Asia    28.801  779.445314
# 1     Afghanistan     9240934      Asia    30.332  820.853030
# 2     Afghanistan    10267083      Asia    31.997  853.100710
# 3     Afghanistan    11537966      Asia    34.020  836.197138
# 4     Afghanistan    13079460      Asia    36.088  739.981106
# ...           ...         ...       ...       ...         ...
# 1699     Zimbabwe     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe    12311143    Africa    43.487  469.709298
#
# [1704 rows x 5 columns]

# %%
df.head(2)
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030

# %%
df["New"]=df["gdp_cap"]/df["life_exp"]

# %%
df.head(2)
# Out:
#        country  year  population continent  life_exp     gdp_cap        New
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314  27.063134
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030  27.062278

# %%
a=df["country"]

# %%
a
# Out:
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
#            ...
# 1699       Zimbabwe
# 1700       Zimbabwe
# 1701       Zimbabwe
# 1702       Zimbabwe
# 1703       Zimbabwe
# Name: country, Length: 1704, dtype: object

# %%
type(a)
# Out:
# pandas.core.series.Series

# %%
a[1:5]
# Out:
# 1    Afghanistan
# 2    Afghanistan
# 3    Afghanistan
# 4    Afghanistan
# Name: country, dtype: object

# %%
a[50:55]
# Out:
# 50    Argentina
# 51    Argentina
# 52    Argentina
# 53    Argentina
# 54    Argentina
# Name: country, dtype: object

# %%
a[1111]
# Out:
# 'Nicaragua'

# %%
a.index
# Out:
# RangeIndex(start=0, stop=1704, step=1)

# %%
a.index=[i for i in range(1,1705)]

# %%
a
# Out:
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
# 5       Afghanistan
#            ...
# 1700       Zimbabwe
# 1701       Zimbabwe
# 1702       Zimbabwe
# 1703       Zimbabwe
# 1704       Zimbabwe
# Name: country, Length: 1704, dtype: object

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap        New
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314  27.063134
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030  27.062278
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710  26.661897
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138  24.579575
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106  20.504908
# ...           ...   ...         ...       ...       ...         ...        ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306  11.325517
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786  11.484850
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960  16.929436
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623  16.805587
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298  10.801143
#
# [1704 rows x 7 columns]

# %%
df.set_index("country")
# Out:
#              year  population continent  life_exp     gdp_cap        New
# country
# Afghanistan  1952     8425333      Asia    28.801  779.445314  27.063134
# Afghanistan  1957     9240934      Asia    30.332  820.853030  27.062278
# Afghanistan  1962    10267083      Asia    31.997  853.100710  26.661897
# Afghanistan  1967    11537966      Asia    34.020  836.197138  24.579575
# Afghanistan  1972    13079460      Asia    36.088  739.981106  20.504908
# ...           ...         ...       ...       ...         ...        ...
# Zimbabwe     1987     9216418    Africa    62.351  706.157306  11.325517
# Zimbabwe     1992    10704340    Africa    60.377  693.420786  11.484850
# Zimbabwe     1997    11404948    Africa    46.809  792.449960  16.929436
# Zimbabwe     2002    11926563    Africa    39.989  672.038623  16.805587
# Zimbabwe     2007    12311143    Africa    43.487  469.709298  10.801143
#
# [1704 rows x 6 columns]

# %%
df.set_index("country",inplace=True)

# %%
df
# Out:
#              year  population continent  life_exp     gdp_cap        New
# country
# Afghanistan  1952     8425333      Asia    28.801  779.445314  27.063134
# Afghanistan  1957     9240934      Asia    30.332  820.853030  27.062278
# Afghanistan  1962    10267083      Asia    31.997  853.100710  26.661897
# Afghanistan  1967    11537966      Asia    34.020  836.197138  24.579575
# Afghanistan  1972    13079460      Asia    36.088  739.981106  20.504908
# ...           ...         ...       ...       ...         ...        ...
# Zimbabwe     1987     9216418    Africa    62.351  706.157306  11.325517
# Zimbabwe     1992    10704340    Africa    60.377  693.420786  11.484850
# Zimbabwe     1997    11404948    Africa    46.809  792.449960  16.929436
# Zimbabwe     2002    11926563    Africa    39.989  672.038623  16.805587
# Zimbabwe     2007    12311143    Africa    43.487  469.709298  10.801143
#
# [1704 rows x 6 columns]

# %%
df.loc["India"]
# Out:
#          year  population continent  life_exp      gdp_cap        New
# country
# India    1952   372000000      Asia    37.373   546.565749  14.624615
# India    1957   409000000      Asia    40.249   590.061996  14.660290
# India    1962   454000000      Asia    43.605   658.347151  15.097974
# India    1967   506000000      Asia    47.193   700.770611  14.849037
# India    1972   567000000      Asia    50.651   724.032527  14.294536
# India    1977   634000000      Asia    54.208   813.337323  15.004009
# India    1982   708000000      Asia    56.596   855.723538  15.119859
# India    1987   788000000      Asia    58.553   976.512676  16.677415
# India    1992   872000000      Asia    60.223  1164.406809  19.334919
# India    1997   959000000      Asia    61.765  1458.817442  23.618837
# India    2002  1034172547      Asia    62.879  1746.769454  27.779854
# India    2007  1110396331      Asia    64.698  2452.210407  37.902414

# %%
df.loc["Afghanistan"]
# Out:
#              year  population continent  life_exp     gdp_cap        New
# country
# Afghanistan  1952     8425333      Asia    28.801  779.445314  27.063134
# Afghanistan  1957     9240934      Asia    30.332  820.853030  27.062278
# Afghanistan  1962    10267083      Asia    31.997  853.100710  26.661897
# Afghanistan  1967    11537966      Asia    34.020  836.197138  24.579575
# Afghanistan  1972    13079460      Asia    36.088  739.981106  20.504908
# Afghanistan  1977    14880372      Asia    38.438  786.113360  20.451464
# Afghanistan  1982    12881816      Asia    39.854  978.011439  24.539856
# Afghanistan  1987    13867957      Asia    40.822  852.395945  20.880798
# Afghanistan  1992    16317921      Asia    41.674  649.341395  15.581451
# Afghanistan  1997    22227415      Asia    41.763  635.341351  15.213020
# Afghanistan  2002    25268405      Asia    42.129  726.734055  17.250209
# Afghanistan  2007    31889923      Asia    43.828  974.580338  22.236478

# %%
df.reset_index()
# Out:
#           country  year  population continent  life_exp     gdp_cap        New
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314  27.063134
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030  27.062278
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710  26.661897
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138  24.579575
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106  20.504908
# ...           ...   ...         ...       ...       ...         ...        ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306  11.325517
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786  11.484850
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960  16.929436
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623  16.805587
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298  10.801143
#
# [1704 rows x 7 columns]

# %%
df
# Out:
#              year  population continent  life_exp     gdp_cap        New
# country
# Afghanistan  1952     8425333      Asia    28.801  779.445314  27.063134
# Afghanistan  1957     9240934      Asia    30.332  820.853030  27.062278
# Afghanistan  1962    10267083      Asia    31.997  853.100710  26.661897
# Afghanistan  1967    11537966      Asia    34.020  836.197138  24.579575
# Afghanistan  1972    13079460      Asia    36.088  739.981106  20.504908
# ...           ...         ...       ...       ...         ...        ...
# Zimbabwe     1987     9216418    Africa    62.351  706.157306  11.325517
# Zimbabwe     1992    10704340    Africa    60.377  693.420786  11.484850
# Zimbabwe     1997    11404948    Africa    46.809  792.449960  16.929436
# Zimbabwe     2002    11926563    Africa    39.989  672.038623  16.805587
# Zimbabwe     2007    12311143    Africa    43.487  469.709298  10.801143
#
# [1704 rows x 6 columns]

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap        New
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314  27.063134
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030  27.062278
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710  26.661897
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138  24.579575
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106  20.504908
# ...           ...   ...         ...       ...       ...         ...        ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306  11.325517
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786  11.484850
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960  16.929436
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623  16.805587
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298  10.801143
#
# [1704 rows x 7 columns]

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1704, step=1)

# %%
df.index=[i for i in range(1,1705)]

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap        New
# 1     Afghanistan  1952     8425333      Asia    28.801  779.445314  27.063134
# 2     Afghanistan  1957     9240934      Asia    30.332  820.853030  27.062278
# 3     Afghanistan  1962    10267083      Asia    31.997  853.100710  26.661897
# 4     Afghanistan  1967    11537966      Asia    34.020  836.197138  24.579575
# 5     Afghanistan  1972    13079460      Asia    36.088  739.981106  20.504908
# ...           ...   ...         ...       ...       ...         ...        ...
# 1700     Zimbabwe  1987     9216418    Africa    62.351  706.157306  11.325517
# 1701     Zimbabwe  1992    10704340    Africa    60.377  693.420786  11.484850
# 1702     Zimbabwe  1997    11404948    Africa    46.809  792.449960  16.929436
# 1703     Zimbabwe  2002    11926563    Africa    39.989  672.038623  16.805587
# 1704     Zimbabwe  2007    12311143    Africa    43.487  469.709298  10.801143
#
# [1704 rows x 7 columns]

# %%
df.loc[2:6]
# Out:
#        country  year  population continent  life_exp     gdp_cap        New
# 2  Afghanistan  1957     9240934      Asia    30.332  820.853030  27.062278
# 3  Afghanistan  1962    10267083      Asia    31.997  853.100710  26.661897
# 4  Afghanistan  1967    11537966      Asia    34.020  836.197138  24.579575
# 5  Afghanistan  1972    13079460      Asia    36.088  739.981106  20.504908
# 6  Afghanistan  1977    14880372      Asia    38.438  786.113360  20.451464

# %%
df.iloc[2:6]
# Out:
#        country  year  population continent  life_exp     gdp_cap        New
# 3  Afghanistan  1962    10267083      Asia    31.997  853.100710  26.661897
# 4  Afghanistan  1967    11537966      Asia    34.020  836.197138  24.579575
# 5  Afghanistan  1972    13079460      Asia    36.088  739.981106  20.504908
# 6  Afghanistan  1977    14880372      Asia    38.438  786.113360  20.451464

# %%
df.loc[1]
# Out:
# country       Afghanistan
# year                 1952
# population        8425333
# continent            Asia
# life_exp           28.801
# gdp_cap        779.445314
# New             27.063134
# Name: 1, dtype: object

# %%
df.iloc[1]
# Out:
# country       Afghanistan
# year                 1957
# population        9240934
# continent            Asia
# life_exp           30.332
# gdp_cap         820.85303
# New             27.062278
# Name: 2, dtype: object

# %%
df.loc[[2,1200,1111]]
# Out:
#           country  year  population continent  life_exp      gdp_cap  \
# 2     Afghanistan  1957     9240934      Asia    30.332   820.853030
# 1200     Paraguay  2007     6667147  Americas    71.752  4172.838464
# 1111    Nicaragua  1982     2979423  Americas    59.298  3470.338156
#
#             New
# 2     27.062278
# 1200  58.156406
# 1111  58.523697

# %%
len(df.index)
# Out:
# 1704

# %%
df.loc[:2]
# Out:
#        country  year  population continent  life_exp     gdp_cap        New
# 1  Afghanistan  1952     8425333      Asia    28.801  779.445314  27.063134
# 2  Afghanistan  1957     9240934      Asia    30.332  820.853030  27.062278

# %%
df.loc[:2,"country":"life_exp"]
# Out:
#        country  year  population continent  life_exp
# 1  Afghanistan  1952     8425333      Asia    28.801
# 2  Afghanistan  1957     9240934      Asia    30.332

# %%
df.iloc[:2,0:5]
# Out:
#        country  year  population continent  life_exp
# 1  Afghanistan  1952     8425333      Asia    28.801
# 2  Afghanistan  1957     9240934      Asia    30.332

# %%
df.loc[:20:2,"country":"life_exp":2]
# Out:
#         country  population  life_exp
# 1   Afghanistan     8425333    28.801
# 3   Afghanistan    10267083    31.997
# 5   Afghanistan    13079460    36.088
# 7   Afghanistan    12881816    39.854
# 9   Afghanistan    16317921    41.674
# 11  Afghanistan    25268405    42.129
# 13      Albania     1282697    55.230
# 15      Albania     1728137    64.820
# 17      Albania     2263554    67.690
# 19      Albania     2780097    70.420

# %%
df.duplicated()
# Out:
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
#         ...
# 1700    False
# 1701    False
# 1702    False
# 1703    False
# 1704    False
# Length: 1704, dtype: bool

# %%
df.loc[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [country, year, population, continent, life_exp, gdp_cap, New]
# Index: []

# %%
df.sort_values(["year"])
# Out:
#                  country  year  population continent  life_exp       gdp_cap  \
# 1            Afghanistan  1952     8425333      Asia    28.801    779.445314
# 529               France  1952    42459667    Europe    67.410   7029.809327
# 541                Gabon  1952      420702    Africa    37.003   4293.476475
# 1657  West Bank and Gaza  1952     1030585      Asia    43.160   1515.592329
# 553               Gambia  1952      284320    Africa    30.000    485.230659
# ...                  ...   ...         ...       ...       ...           ...
# 1128               Niger  2007    12894865    Africa    56.867    619.676892
# 1140             Nigeria  2007   135031164    Africa    46.859   2013.977305
# 1152              Norway  2007     4627926    Europe    80.196  49357.190170
# 1176            Pakistan  2007   169270617      Asia    65.483   2605.947580
# 1704            Zimbabwe  2007    12311143    Africa    43.487    469.709298
#
#              New
# 1      27.063134
# ...

# %%
df.sort_values?

# %%
df.sort_values(["year"],ascending=False)
# Out:
#                 country  year  population continent  life_exp        gdp_cap  \
# 1704           Zimbabwe  2007    12311143    Africa    43.487     469.709298
# 492   Equatorial Guinea  2007      551201    Africa    51.579   12154.089750
# 516            Ethiopia  2007    76511887    Africa    52.947     690.805576
# 528             Finland  2007     5238460    Europe    79.313   33207.084400
# 540              France  2007    61083916    Europe    80.657   30470.016700
# ...                 ...   ...         ...       ...       ...            ...
# 1117              Niger  1952     3379468    Africa    37.444     761.879376
# 1129            Nigeria  1952    33119096    Africa    36.324    1077.281856
# 1141             Norway  1952     3327728    Europe    72.670   10095.421720
# 1153               Oman  1952      507833      Asia    37.578    1828.230307
# 853              Kuwait  1952      160000      Asia    55.565  108382.352900
#
#               New
# 1704    10.801143
# ...

# %%
a=pd.DataFrame({"A":[10,20,30],
               "B":[11,22,33]})

b=pd.DataFrame({"A":[1,2,3],
               "C":[0.1,0.2,0.3]})

# %%
a
# Out:
#     A   B
# 0  10  11
# 1  20  22
# 2  30  33

# %%
b
# Out:
#    A    C
# 0  1  0.1
# 1  2  0.2
# 2  3  0.3

# %%
pd.concat([a,b])
# Out:
#     A     B    C
# 0  10  11.0  NaN
# 1  20  22.0  NaN
# 2  30  33.0  NaN
# 0   1   NaN  0.1
# 1   2   NaN  0.2
# 2   3   NaN  0.3

# %%
pd.concat?

# %%
pd.concat([a,b],axis=1)
# Out:
#     A   B  A    C
# 0  10  11  1  0.1
# 1  20  22  2  0.2
# 2  30  33  3  0.3

# %%
pd.merge?

# %%
user=pd.DataFrame({"userid":[1,2,3],
                  "name":["A","B","C"]})
user
# Out:
#    userid name
# 0       1    A
# 1       2    B
# 2       3    C

# %%
msg=pd.DataFrame({"userid":[1,1,2,4],
                 "msg":["Hello","Workd","hmm","kool"]})
msg
# Out:
#    userid    msg
# 0       1  Hello
# 1       1  Workd
# 2       2    hmm
# 3       4   kool

# %%
user.merge(msg)
# Out:
#    userid name    msg
# 0       1    A  Hello
# 1       1    A  Workd
# 2       2    B    hmm

# %%
user.merge(msg,on="userid")
# Out:
#    userid name    msg
# 0       1    A  Hello
# 1       1    A  Workd
# 2       2    B    hmm

# %%
user.merge(msg,on="userid",how="outer")
# Out:
#    userid name    msg
# 0       1    A  Hello
# 1       1    A  Workd
# 2       2    B    hmm
# 3       3    C    NaN
# 4       4  NaN   kool

# %%
user.merge(msg,on="userid",how="right")
# Out:
#    userid name    msg
# 0       1    A  Hello
# 1       1    A  Workd
# 2       2    B    hmm
# 3       4  NaN   kool

# %%
ls
# Out:
# MatplotLib conti. + Seaborn.ipynb  Pfizer_1.csv
# Matplotlib.ipynb                   directors.csv
# Matplotlib_Revision.ipynb          figure.png
# Pandas_4.ipynb                     gapminder.csv
# Pandas_5.ipynb                     jupyterthemes.ipynb
# Pandas_Rev_conti.ipynb             movies.csv
# Pandas_Revision.ipynb

# %%
dire=pd.read_csv("directors.csv")
mov=pd.read_csv("movies.csv")

# %%
dire
# Out:
#       Unnamed: 0      director_name    id gender
# 0              0      James Cameron  4762   Male
# 1              1     Gore Verbinski  4763   Male
# 2              2         Sam Mendes  4764   Male
# 3              3  Christopher Nolan  4765   Male
# 4              4     Andrew Stanton  4766   Male
# ...          ...                ...   ...    ...
# 2344        2344      Shane Carruth  7106   Male
# 2345        2345   Neill Dela Llana  7107    NaN
# 2346        2346        Scott Smith  7108    NaN
# 2347        2347        Daniel Hsia  7109   Male
# 2348        2348   Brian Herzlinger  7110   Male
#
# [2349 rows x 4 columns]

# %%
mov
# Out:
#       Unnamed: 0     id     budget  popularity     revenue  \
# 0              0  43597  237000000         150  2787965087
# 1              1  43598  300000000         139   961000000
# 2              2  43599  245000000         107   880674609
# 3              3  43600  250000000         112  1084939099
# 4              5  43602  258000000         115   890871626
# ...          ...    ...        ...         ...         ...
# 1460        4736  48363          0           3      321952
# 1461        4743  48370      27000          19     3151130
# 1462        4748  48375          0           7           0
# 1463        4749  48376          0           3           0
# 1464        4768  48395     220000          14     2040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# ...

# %%
dire=pd.read_csv("directors.csv",index_col=0)
mov=pd.read_csv("movies.csv",index_col=0)

# %%
dire
# Out:
#           director_name    id gender
# 0         James Cameron  4762   Male
# 1        Gore Verbinski  4763   Male
# 2            Sam Mendes  4764   Male
# 3     Christopher Nolan  4765   Male
# 4        Andrew Stanton  4766   Male
# ...                 ...   ...    ...
# 2344      Shane Carruth  7106   Male
# 2345   Neill Dela Llana  7107    NaN
# 2346        Scott Smith  7108    NaN
# 2347        Daniel Hsia  7109   Male
# 2348   Brian Herzlinger  7110   Male
#
# [2349 rows x 3 columns]

# %%
mov
# Out:
#          id     budget  popularity     revenue  \
# 0     43597  237000000         150  2787965087
# 1     43598  300000000         139   961000000
# 2     43599  245000000         107   880674609
# 3     43600  250000000         112  1084939099
# 5     43602  258000000         115   890871626
# ...     ...        ...         ...         ...
# 4736  48363          0           3      321952
# 4743  48370      27000          19     3151130
# 4748  48375          0           7           0
# 4749  48376          0           3           0
# 4768  48395     220000          14     2040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# ...

# %%
df=mov.merge(dire,how="left",left_on="director_id",right_on="id")

# %%
df
# Out:
#        id_x     budget  popularity     revenue  \
# 0     43597  237000000         150  2787965087
# 1     43598  300000000         139   961000000
# 2     43599  245000000         107   880674609
# 3     43600  250000000         112  1084939099
# 4     43602  258000000         115   890871626
# ...     ...        ...         ...         ...
# 1460  48363          0           3      321952
# 1461  48370      27000          19     3151130
# 1462  48375          0           7           0
# 1463  48376          0           3           0
# 1464  48395     220000          14     2040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# ...

# %%
df.loc[df["budget"]>100000,["title","director_name"]]
# Out:
#                                          title      director_name
# 0                                       Avatar      James Cameron
# 1     Pirates of the Caribbean: At World's End     Gore Verbinski
# 2                                      Spectre         Sam Mendes
# 3                        The Dark Knight Rises  Christopher Nolan
# 4                                 Spider-Man 3          Sam Raimi
# ...                                        ...                ...
# 1450                                   Mad Max      George Miller
# 1451                                  Swingers         Doug Liman
# 1454                                   Tadpole        Gary Winick
# 1455                                Roger & Me      Michael Moore
# 1464                               El Mariachi   Robert Rodriguez
#
# [1325 rows x 2 columns]

# %%
df.sort_values("budget")
# Out:
#        id_x     budget  popularity     revenue  \
# 1095  45973          0           8           0
# 1098  45990          0           3    90508336
# 1104  46021          0          10           0
# 1115  46055          0           9           0
# 351   44198          0           9           0
# ...     ...        ...         ...         ...
# 9     43610  255000000          49    89289910
# 4     43602  258000000         115   890871626
# 6     43607  270000000          57   391081192
# 1     43598  300000000         139   961000000
# 12    43614  380000000         135  1045713802
#
#                                             title  vote_average  vote_count  \
# 1095                                Anything Else           6.2         149
# 1098                           Madea Goes to Jail           6.4          52
# 1104                                A Simple Plan           6.9         187
# 1115                                Varsity Blues           6.0         122
# ...

# %%
df.sort_values("budget",ascending=False)
# Out:
#        id_x     budget  popularity     revenue  \
# 12    43614  380000000         135  1045713802
# 1     43598  300000000         139   961000000
# 6     43607  270000000          57   391081192
# 4     43602  258000000         115   890871626
# 9     43610  255000000          49    89289910
# ...     ...        ...         ...         ...
# 1181  46306          0           9     5405500
# 687   44918          0           5           0
# 1192  46367          0           4           0
# 1196  46376          0           2           0
# 271   44050          0          25           0
#
#                                             title  vote_average  vote_count  \
# 12    Pirates of the Caribbean: On Stranger Tides           6.4        4948
# 1        Pirates of the Caribbean: At World's End           6.9        4500
# 6                                Superman Returns           5.4        1400
# 4                                    Spider-Man 3           5.9        3576
# ...

# %%
df
# Out:
#        id_x     budget  popularity     revenue  \
# 0     43597  237000000         150  2787965087
# 1     43598  300000000         139   961000000
# 2     43599  245000000         107   880674609
# 3     43600  250000000         112  1084939099
# 4     43602  258000000         115   890871626
# ...     ...        ...         ...         ...
# 1460  48363          0           3      321952
# 1461  48370      27000          19     3151130
# 1462  48375          0           7           0
# 1463  48376          0           3           0
# 1464  48395     220000          14     2040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# ...

# %%
df.loc[df["director_name"]=="James Cameron"].count()
# Out:
# id_x             7
# budget           7
# popularity       7
# revenue          7
# title            7
# vote_average     7
# vote_count       7
# director_id      7
# year             7
# month            7
# day              7
# director_name    7
# id_y             7
# gender           7
# dtype: int64

# %%
df["director_name"].value_counts()
# Out:
# Steven Spielberg      26
# Martin Scorsese       19
# Clint Eastwood        19
# Woody Allen           18
# Ridley Scott          16
#                       ..
# Tim Hill               5
# Jonathan Liebesman     5
# Roman Polanski         5
# Larry Charles          5
# Nicole Holofcener      5
# Name: director_name, Length: 199, dtype: int64

# %%
df.groupby("director_name")

# %%
df.groupby("director_name")["budget"].max()
# Out:
# director_name
# Adam McKay                     100000000
# Adam Shankman                   80000000
# Alejandro González Iñárritu    135000000
# Alex Proyas                    140000000
# Alexander Payne                 30000000
#                                  ...
# Wes Craven                      40000000
# Wolfgang Petersen              175000000
# Woody Allen                     30000000
# Zack Snyder                    250000000
# Zhang Yimou                     94000000
# Name: budget, Length: 199, dtype: int64

# %%
df
# Out:
#        id_x     budget  popularity     revenue  \
# 0     43597  237000000         150  2787965087
# 1     43598  300000000         139   961000000
# 2     43599  245000000         107   880674609
# 3     43600  250000000         112  1084939099
# 4     43602  258000000         115   890871626
# ...     ...        ...         ...         ...
# 1460  48363          0           3      321952
# 1461  48370      27000          19     3151130
# 1462  48375          0           7           0
# 1463  48376          0           3           0
# 1464  48395     220000          14     2040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# ...

# %%
df.groupby("director_name")["revenue"].max()
# Out:
# director_name
# Adam McKay                     173649015
# Adam Shankman                  212874442
# Alejandro González Iñárritu    532950503
# Alex Proyas                    347234916
# Alexander Payne                177243185
#                                  ...
# Wes Craven                     173046663
# Wolfgang Petersen              497409852
# Woody Allen                    151119219
# Zack Snyder                    873260194
# Zhang Yimou                    177394432
# Name: revenue, Length: 199, dtype: int64

# %%
df.groupby("director_name")["title"].count().sort_values()
# Out:
# director_name
# Kevin Reynolds       5
# George Clooney       5
# Gavin O'Connor       5
# Gary Winick          5
# Michael Apted        5
#                     ..
# Spike Lee           16
# Woody Allen         18
# Clint Eastwood      19
# Martin Scorsese     19
# Steven Spielberg    26
# Name: title, Length: 199, dtype: int64

# %%
df.groupby("year")

# %%
df.groupby("year")["budget"].max()
# Out:
# year
# 1976      3800000
# 1977     20000000
# 1978     55000000
# 1979     35000000
# 1980     27000000
# 1981     28000000
# 1982     28000000
# 1983     40600000
# 1984     58000000
# 1985     31000000
# 1986     25000000
# 1987     40000000
# 1988     28000000
# 1989     70000000
# 1990     70000000
# 1991    100000000
# 1992     80000000
# 1993     85000000
# 1994    115000000
# 1995    175000000
# 1996    100000000
# 1997    200000000
# 1998    140000000
# 1999    170000000
# 2000    125000000
# 2001    140000000
# 2002    140000000
# 2003    150000000
# 2004    200000000
# 2005    207000000
# 2006    270000000
# 2007    300000000
# 2008    225000000
# 2009    237000000
# 2010    200000000
# 2011    380000000
# 2012    250000000
# 2013    255000000
# 2014    250000000
# 2015    245000000
# 2016    250000000
# Name: budget, dtype: int64

# %%
df.groupby("year")["budget"].count()
# Out:
# year
# 1976     3
# 1977     6
# 1978     5
# 1979     4
# 1980     8
# 1981    11
# 1982    10
# 1983     9
# 1984    10
# 1985    14
# 1986    11
# 1987    12
# 1988    13
# 1989    18
# 1990    18
# 1991    12
# 1992    22
# 1993    18
# 1994    31
# 1995    33
# 1996    46
# 1997    46
# 1998    45
# 1999    64
# 2000    59
# 2001    62
# 2002    69
# 2003    58
# 2004    61
# 2005    71
# 2006    73
# 2007    54
# 2008    67
# 2009    66
# 2010    63
# 2011    67
# 2012    49
# 2013    57
# 2014    53
# 2015    41
# 2016    26
# Name: budget, dtype: int64

# %%
df
# Out:
#        id_x     budget  popularity     revenue  \
# 0     43597  237000000         150  2787965087
# 1     43598  300000000         139   961000000
# 2     43599  245000000         107   880674609
# 3     43600  250000000         112  1084939099
# 4     43602  258000000         115   890871626
# ...     ...        ...         ...         ...
# 1460  48363          0           3      321952
# 1461  48370      27000          19     3151130
# 1462  48375          0           7           0
# 1463  48376          0           3           0
# 1464  48395     220000          14     2040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# ...

# %%
df.groupby("year")["popularity"].max()
# Out:
# year
# 1976     58
# 1977     52
# 1978     48
# 1979     94
# 1980     44
# 1981     68
# 1982     94
# 1983     70
# 1984     74
# 1985     76
# 1986     67
# 1987     50
# 1988     66
# 1989     80
# 1990     63
# 1991    101
# 1992     81
# 1993    104
# 1994    138
# 1995     79
# 1996     75
# 1997    109
# 1998     76
# 1999    146
# 2000     95
# 2001    138
# 2002    132
# 2003    271
# 2004     95
# 2005    115
# 2006    145
# 2007    139
# 2008    187
# 2009    150
# 2010    167
# 2011    135
# 2012    112
# 2013     99
# 2014    724
# 2015    434
# 2016    155
# Name: popularity, dtype: int64

# %%
def cal_exp(x):
    x=x-x.mean()
    return x

df["new"]=df.groupby("director_name")["revenue"].transform(cal_exp)

# %%
df["new"]=df["new"]/1000000

# %%
df
# Out:
#        id_x     budget  popularity     revenue  \
# 0     43597  237000000         150  2787965087
# 1     43598  300000000         139   961000000
# 2     43599  245000000         107   880674609
# 3     43600  250000000         112  1084939099
# 4     43602  258000000         115   890871626
# ...     ...        ...         ...         ...
# 1460  48363          0           3      321952
# 1461  48370      27000          19     3151130
# 1462  48375          0           7           0
# 1463  48376          0           3           0
# 1464  48395     220000          14     2040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# ...
