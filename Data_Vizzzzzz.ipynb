# %%
ls
# Out:
# Data Via conti..ipynb              Probability Day 1.ipynb
# Data Viz with seaborn.ipynb        Probability Day 2.ipynb
# Data_Vizzzzzz.ipynb                Untitled.ipynb
# MatplotLib conti. + Seaborn.ipynb  directors.csv
# Matplotlib.ipynb                   drive.google.com/
# Matplotlib_Revision.ipynb          figure.png
# Netflix project.ipynb              gapminder.csv
# Pandas_4.ipynb                     jupyterthemes.ipynb
# Pandas_5.ipynb                     movies.csv
# Pandas_Rev_conti.ipynb             numpy_pandas_revision.ipynb
# Pandas_Revision.ipynb              prob_01_basic_definitions/
# Pfizer_1.csv

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %%
x=[1,2,3,4]
y=[5,6,7,8]
plt.plot(x,y)

# %%
x=[1,2,3,4,3,4]
y=[2,4,6,2,3,8]
plt.plot(x,y)

# %%
x_val=[1,7,3,5,9,2]
plt.plot(x_val)
plt.savefig("./figure")

# %%
ls
# Out:
# Data Via conti..ipynb              Probability Day 1.ipynb
# Data Viz with seaborn.ipynb        Probability Day 2.ipynb
# Data_Vizzzzzz.ipynb                Untitled.ipynb
# MatplotLib conti. + Seaborn.ipynb  directors.csv
# Matplotlib.ipynb                   drive.google.com/
# Matplotlib_Revision.ipynb          figure.png
# Netflix project.ipynb              gapminder.csv
# Pandas_4.ipynb                     jupyterthemes.ipynb
# Pandas_5.ipynb                     movies.csv
# Pandas_Rev_conti.ipynb             numpy_pandas_revision.ipynb
# Pandas_Revision.ipynb              prob_01_basic_definitions/
# Pfizer_1.csv

# %%
pwd
# Out:
# '/Users/jitendranathmahato/Downloads/Scaler'

# %%
x=[-3,-2,-1,0,1,2,3]
y=[9,4,1,0,1,4,9]
plt.plot(x,y)

# %%
x=np.arange(-3,3,0.1)
y=x**2
plt.plot(x,y)

# %%
x=np.arange(-3,3,0.1)
y=x**2
plt.plot(x,y)
plt.xticks(np.arange(-3,3,0.1))
plt.show()

# %%
x=np.arange(-3,3,0.1)
y=x**2
plt.plot(x,y)
plt.yticks(np.arange(-3,3,0.1))
plt.show()

# %%
x=np.arange(-3,3,0.1)
y=x**2
plt.plot(x,y)
plt.xticks(np.arange(-3,3,0.8))
plt.yticks(np.arange(-3,3,0.9))
plt.show()

# %%
x=np.arange(-3,3,0.1)
y=x**2
plt.plot(x,y)
plt.xticks(np.arange(-3,3,0.8))
plt.yticks(np.arange(-3,3,0.9))
plt.show()
